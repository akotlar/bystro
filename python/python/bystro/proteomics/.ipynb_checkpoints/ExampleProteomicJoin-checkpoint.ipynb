# %%
ABUNDANCE_FILENAME = 'TMT_4plex/abundance_gene_MD.tsv'
ANNOTATION_FILENAME = 'TMT_4plex/experiment_annotation.tsv'
INDEX_NAME = '656a505afdd014a1f3e3fddd_63ddc9ce1e740e0020c39928'
USER_QUERY = "synonymous || (nearest.refSeq.dist > -100 && nearest.refSeq.dist <= 0)"

from bystro.proteomics.annotation_interface import OPENSEARCH_CONFIG, get_annotation_result_from_query, join_annotation_result_to_proteomics_dataset

from bystro.proteomics.fragpipe_tandem_mass_tag import TandemMassTagDataset, load_tandem_mass_tag_dataset
from opensearchpy import OpenSearch

client = OpenSearch(**OPENSEARCH_CONFIG)

# %%
tmt_dataset = load_tandem_mass_tag_dataset(abundance_filename=ABUNDANCE_FILENAME,
                                           annotation_filename=ANNOTATION_FILENAME)

# %%
tmt_dataset.annotation_df
# Out:
#                plex channel  sample_name condition  replicate
# sample
# CPT0088900003    16     126  C3N-01179-T     Tumor          1
# CPT0079270003    16    127N  C3L-00606-T     Tumor          1
# CPT0088920001    16    127C  C3N-01179-N       NAT          1
# CPT0079300001    16    128N  C3L-00606-N       NAT          1
# CPT0088550004    16    128C  C3N-01648-T     Tumor          1
# QC6              16    129N          QC6        QC          1
# CPT0014450004    16    129C  C3N-00242-T     Tumor          1
# CPT0088570001    16    130N  C3N-01648-N       NAT          1
# CPT0014470001    16    130C  C3N-00242-N       NAT          1
# pool16           16    131N       pool16    pool16          1
# CPT0006730001    17     126  C3L-00418-N       NAT          1
# CPT0069190001    17    127N  C3N-00577-N       NAT          1
# CPT0092730003    17    127C  C3L-01882-T     Tumor          1
# CPT0092740003    17    128N  C3L-01882-N       NAT          1
# QC7              17    128C          QC7        QC          1
# CPT0006630003    17    129N  C3L-00418-T     Tumor          1
# CPT0025920001    17    129C  C3N-00733-N       NAT          1
# CPT0025880003    17    130N  C3N-00733-T     Tumor          1
# CPT0069160003    17    130C  C3N-00577-T     Tumor          1
# pool17           17    131N       pool17    pool17          1
# CPT0007870001    18     126  C3L-00910-N       NAT          1
# CPT0001270001    18    127N  C3L-00079-N       NAT          1
# CPT0077110003    18    127C  C3N-01522-T     Tumor          1
# QC8              18    128N          QC8        QC          1
# CPT0077140001    18    128C  C3N-01522-N       NAT          1
# CPT0001260009    18    129N  C3L-00079-T     Tumor          1
# CPT0076350001    18    129C  C3N-01220-N       NAT          1
# CPT0076330003    18    130N  C3N-01220-T     Tumor          1
# CPT0007860003    18    130C  C3L-00910-T     Tumor          1
# pool18           18    131N       pool18    pool18          1
# CPT0079380003    19     126  C3L-01283-T     Tumor          1
# CPT0015810003    19    127N  C3L-00813-T     Tumor          1
# CPT0086030003    19    127C  C3L-01560-T     Tumor          1
# CPT0085670003    19    128N  C3L-01557-T     Tumor          1
# CPT0025230003    19    128C  C3L-00799-T     Tumor          1
# CPT0065750003    19    129N  C3L-00796-T     Tumor          1
# CPT0015730003    19    129C  C3L-00792-T     Tumor          1
# CPT0078800003    19    130N  C3N-00832-T     Tumor          1
# CPT0079230003    19    130C  C3L-01228-T     Tumor          1
# pool19           19    131N       pool19    pool19          1

# %%
tmt_dataset.abundance_df
# Out:
#         NumberPSM ProteinID  MaxPepProb  ReferenceIntensity  CPT0088900003  \
# Index
# A1BG          324    P04217         1.0           30.044336       0.665648
# A1CF           94    Q9NQ94         1.0           26.115335       0.091328
# A2M          1418    P01023         1.0           30.802090       0.956687
# AAAS           50    Q9NRG9         1.0           24.422673      -0.005041
# AACS           65    Q86V21         1.0           27.520496      -0.885569
# ...           ...       ...         ...                 ...            ...
# ZXDC            3    Q2QGD7         1.0           18.376887      -0.654188
# ZYG11B         37    Q9C0D3         1.0           23.758588       0.026481
# ZYX           293    Q15942         1.0           29.773687       0.267343
# ZZEF1         204    O43149         1.0           27.258125      -0.024987
# ZZZ3            8    Q8IYH5         1.0           21.352066      -0.001982
#
#         CPT0079270003  CPT0088920001  CPT0079300001  CPT0088550004       QC6  \
# Index
# A1BG         0.156983      -0.040208       0.647754      -0.948779 -1.029197
# A1CF         0.228538       0.641523      -0.936936      -1.625079 -1.809748
# A2M         -0.231766       0.095571       0.859875      -0.668738 -0.657280
# AAAS         0.081379      -0.132121       0.102784      -0.097407 -0.096363
# AACS        -0.604937       0.115300       0.116263      -0.682289  0.282590
# ...               ...            ...            ...            ...       ...
# ZXDC        -1.424725       0.296665       1.030376      -1.178351  2.556440
# ZYG11B       0.128192       0.121819      -0.063792      -0.385797  0.813266
# ZYX          0.039754      -0.215753       0.027095       0.760614 -0.924936
# ZZEF1        0.164748       0.190638      -0.152120       0.393652 -0.031325
# ZZZ3         0.069956      -0.139105       0.117753       0.170123  0.289835
#
#         ...  CPT0007860003  CPT0079380003  CPT0015810003  CPT0086030003  \
# Index   ...
# A1BG    ...       0.800228      -0.034147      -0.056787       0.721216
# A1CF    ...       0.443220      -0.679189      -0.447859      -0.529476
# A2M     ...       0.559026      -0.546317       0.272841       0.459240
# AAAS    ...       0.528265      -0.056627      -0.020744      -0.148636
# AACS    ...      -0.414655       0.244193       0.196228      -0.017570
# ...     ...            ...            ...            ...            ...
# ZXDC    ...            NaN            NaN            NaN            NaN
# ZYG11B  ...       0.208455      -0.231912      -0.054855       0.166195
# ZYX     ...      -0.076070       0.416068       0.058444       0.080343
# ZZEF1   ...       0.111746       0.082833      -0.011096       0.175544
# ZZZ3    ...      -0.175774       2.128942      -0.799764      -0.475718
#
#         CPT0085670003  CPT0025230003  CPT0065750003  CPT0015730003  \
# Index
# A1BG         0.282223       0.107007       0.947105      -0.203403
# A1CF         0.173284      -1.745636      -0.209171      -0.472092
# A2M          0.148868       0.224759       0.530004       0.657324
# AAAS         0.241928       0.105649      -0.047757      -0.022935
# AACS        -1.114966      -0.112935       0.371002       0.215173
# ...               ...            ...            ...            ...
# ZXDC              NaN            NaN            NaN            NaN
# ZYG11B      -0.252650       0.315162       0.163858      -0.032966
# ZYX          0.349072       0.084721       0.112083      -0.211234
# ZZEF1       -0.396408       0.132819       0.178419       0.299018
# ZZZ3         0.147356      -0.051070      -0.613472      -0.525090
#
#         CPT0078800003  CPT0079230003
# Index
# A1BG        -0.612417       0.528959
# A1CF        -0.114567       0.435046
# A2M         -1.356194       1.095773
# AAAS         0.072918      -0.017612
# AACS         0.740686      -0.320558
# ...               ...            ...
# ZXDC              NaN            NaN
# ZYG11B       0.091383       0.206972
# ZYX         -0.118319       0.239550
# ZZEF1        0.124616       0.132231
# ZZZ3         0.381936       0.325225
#
# [10835 rows x 40 columns]

# %%
from bystro.proteomics.annotation_interface import OPENSEARCH_CONFIG, get_annotation_result_from_query, join_annotation_result_to_proteomics_dataset
from opensearchpy import OpenSearch
from bystro.search.utils.opensearch import gather_opensearch_args

query_result_df = get_annotation_result_from_query(
    USER_QUERY, INDEX_NAME, client  # type: ignore
)

def fake_samples(x):
    if x == '1805':
        return 'CPT0079270003'
    if x == '1847':
        return 'CPT0088550004'
    if x == '4805':
        return 'CPT0088920001'
        

query_result_df['sample_id'] = query_result_df['sample_id'].apply(fake_samples)

print(query_result_df)
# Out:
#         sample_id  chrom       pos ref alt gene_name  dosage
# 0   CPT0079270003  chr15  41146880   T   C    SPINT1     1.0
# 1   CPT0088550004  chr15  41146880   T   C    SPINT1     1.0
# 2   CPT0088920001  chr15  41146880   T   C    SPINT1     1.0
# 3            None  chr15  41146880   T   C    SPINT1     2.0
# 4            None  chr15  41146880   T   C    SPINT1     NaN
# ..            ...    ...       ...  ..  ..       ...     ...
# 2            None   chr2  26399214   G   A    GAREM2     NaN
# 0   CPT0079270003   chr2  26455127   G   A     HADHA     1.0
# 1   CPT0088550004   chr2  26455127   G   A     HADHA     2.0
# 2   CPT0088920001   chr2  26455127   G   A     HADHA     2.0
# 3            None   chr2  26455127   G   A     HADHA     NaN
#
# [14843 rows x 7 columns]

# %%
df = join_annotation_result_to_proteomics_dataset(
    query_result_df=query_result_df,
    tmt_dataset=tmt_dataset)

# %%
df
# Out:
#           sample_id  chrom       pos ref alt gene_name  dosage     value
# 0     CPT0079270003  chr15  41146880   T   C    SPINT1     1.0  0.066650
# 1     CPT0079270003  chr15  41148199   C   T    SPINT1     1.0  0.066650
# 2     CPT0079270003  chr15  41149161   G   C    SPINT1     1.0  0.066650
# 3     CPT0088550004  chr15  41146880   T   C    SPINT1     1.0 -1.251401
# 4     CPT0088550004  chr15  41148199   C   T    SPINT1     1.0 -1.251401
# ...             ...    ...       ...  ..  ..       ...     ...       ...
# 4785  CPT0088920001  chr15  57967219   T   C     MYZAP     2.0 -0.300454
# 4786  CPT0088550004  chr15  57967219   T   C     MYZAP     2.0 -0.772029
# 4787  CPT0079270003  chr17   7761926   C   T     NAA38     1.0 -0.015347
# 4788  CPT0088550004   chr2  26455127   G   A     HADHA     2.0 -0.618320
# 4789  CPT0088920001   chr2  26455127   G   A     HADHA     2.0  0.349481
#
# [4790 rows x 8 columns]

# %%
## Plot Stuff
# 1) Mom, dad, child for a given gene, a dot plot
# 2) Make a bar plot, of mom dad child of all genes
# 3) Condition on your favorite variant, and show the dosages
# 4) Average abundance of the protein, and a different abundance 
# 5) Average abundance by allele type

# %%
# Python code to illustrate 
# working of try()  
def divide(x, y): 
    try: 
        # Floor Division : Gives only Fractional 
        # Part as Answer 
        result = x // y 
    except ZeroDivisionError: 
        print("Sorry ! You are dividing by zero ") 
        raise
    else:
        print("Yeah ! Your answer is :", result) 
    finally:  
        # this block is always executed   
        # regardless of exception generation.  
        print('This is always executed')   
 
# Look at parameters and note the working of Program 
divide(3, 2) 
divide(3, 0)
# Out:
# Yeah ! Your answer is : 1
# This is always executed
# Sorry ! You are dividing by zero
# This is always executed
