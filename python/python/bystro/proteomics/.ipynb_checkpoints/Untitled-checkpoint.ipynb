# %%
import pandas as pd
import polars as pl

# %%
# !pip install opensearch-py-ml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.2/156.2 kB 10.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.2/143.2 kB 17.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 92.2 MB/s eta 0:00:000m eta 0:00:0101:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.7/310.7 kB 30.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 74.2 MB/s eta 0:00:0031m126.4 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 70.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 99.7 MB/s eta 0:00:000m eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.1/103.1 kB 13.3 MB/s eta 0:00:00
# ...

# %%
# !pip install --upgrade polars
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.5/28.5 MB 61.0 MB/s eta 0:00:000m eta 0:00:010:00:01
# ...

# %%
# !pip install --upgrade pylance
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 61.3 MB/s eta 0:00:000m eta 0:00:0136m0:00:01
# ...

# %%
tables = {"refSeq": [{"a":[1], "b": 2}, {"a":[31, "b": 4}]}

# %%
t = pl.DataFrame(tables)

# %%
t[t['refSeq']['a'] == 1 &  t['refSeq']['b'] == 2
# Out:
# [1]

# %%
t['refSeq'][0]['a'] == [1]
# Out:
# True

# %%
t[t['refSeq'][0]['a'][0] == 3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 t[t['refSeq']['a'][0] == 3]
#
# File ~/miniconda3/envs/bystro/lib/python3.10/site-packages/polars/series/series.py:1083, in Series.__getitem__(self, item)
#    1078         raise ValueError(
#    1079             "cannot use `__getitem__` with index values containing nulls"
#    1080         )
#    1081     return self._take_with_series(idx_series)
# -> 1083 raise TypeError(
#    1084     f"cannot use `__getitem__` on Series of dtype {self.dtype!r}"
#    1085     f" with argument {item!r} of type {type(item).__name__!r}"
#    1086 )
#
# TypeError: cannot use `__getitem__` on Series of dtype Struct([Field('a', List(Int64)), Field('b', Int64)]) with argument 'a' of type 'str'

# %%
p = pd.DataFrame(tables)

# %%
p[p['refSeq'][0]['a'][0] == 1, ]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/bystro/lib/python3.10/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (True,)
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 p[p['refSeq'][0]['a'][0] == 1, ]
#
# ...
